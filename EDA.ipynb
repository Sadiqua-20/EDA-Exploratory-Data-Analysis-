# %% [markdown]
# #**EDA - 1**

# %% [markdown]
# ## **About - Dataset:**##

# %% [markdown]
# **Here is the dataset link:** https://drive.google.com/file/d/1iKy23bMtEQShF_weneRNnYrFmzvpPOI3/view
#
#
# The dataset provided focuses on used bikes, capturing various attributes to analyze the second-hand bike
# market. This dataset helps understand factors influencing resale prices, usage patterns, and market trends for
# used bikes.
#
# ## **Title: Bike Details Dataset**
#
#
# - **=name**: Brand and model name of the bike (Categorical, e.g., "Royal Enfield Classic 350", "Honda Dio").
#
# - **selling_price**: Listed selling price in INR (Numeric, e.g., 175000, 45000).
#
# - **year**: Manufacturing year of the bike (Numeric, e.g., 2019, 2015).
#
# - **seller_type**: Seller category, either "Individual" or "Dealer" (Categorical).
#
# - **owner**: Ownership history, e.g., "1st owner", "2nd owner" (Categorical).
#
# - **km_driven**: Total kilometers driven (Numeric, in km, e.g., 12000, 23000).
#
# - **ex_showroom_price**: Original showroom price in INR (Numeric, e.g., 148114.0, 89643.0, etc,.).
#
#
# **Source:**
# The dataset is available on Kaggle, simulating data commonly observed in real-world online bike resale platforms.
#
#
# **Description:**
#
# The dataset comprises 1061 records of used bike listings. These records include details about the bike's brand and model, selling price, kilometers driven, ownership history, and other attributes. It is particularly useful for resale value prediction, market analysis, and understanding buyer preferences.
#
#
# The dataset consists of 7 features, combining both numeric and categorical data, offering a comprehensive view of the second-hand bike market.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
#finding where is the duplicate value
df[df.duplicated()]
# Out:
#                          name  selling_price  year seller_type      owner  \
# 231     TVS Apache RTR 200 4V          95000  2018  Individual  1st owner
# 508       Bajaj Pulsar 135 LS          20000  2010  Individual  1st owner
# 522         Bajaj Platina 100          20000  2012  Individual  1st owner
# 605  Hero Karizma [2003-2014]          50000  2013  Individual  1st owner
# 607      Honda CB Hornet 160R          70000  2017  Individual  1st owner
# 773  Honda Activa [2000-2015]          23000  2009  Individual  1st owner
#
#      km_driven  ex_showroom_price
# 231       9600                NaN
# 508      80000            64589.0
# 522      16295                NaN
# 605      38000            85766.0
# 607      35000            87719.0
# 773      95000            50267.0

# %%
#fiindng where is the duplicate value with its original value
df[df.duplicated(keep=False)]
# Out:
#                          name  selling_price  year seller_type      owner  \
# 106     TVS Apache RTR 200 4V          95000  2018  Individual  1st owner
# 231     TVS Apache RTR 200 4V          95000  2018  Individual  1st owner
# 329       Bajaj Pulsar 135 LS          20000  2010  Individual  1st owner
# 406  Hero Karizma [2003-2014]          50000  2013  Individual  1st owner
# 470  Honda Activa [2000-2015]          23000  2009  Individual  1st owner
# 503         Bajaj Platina 100          20000  2012  Individual  1st owner
# 508       Bajaj Pulsar 135 LS          20000  2010  Individual  1st owner
# 522         Bajaj Platina 100          20000  2012  Individual  1st owner
# 523      Honda CB Hornet 160R          70000  2017  Individual  1st owner
# 605  Hero Karizma [2003-2014]          50000  2013  Individual  1st owner
# 607      Honda CB Hornet 160R          70000  2017  Individual  1st owner
# 773  Honda Activa [2000-2015]          23000  2009  Individual  1st owner
#
# ...

# %%
#removing duplicates
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#resetting index after removing dupliicates
df.reset_index(drop = True, inplace=True)

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1050                            Activa 3g          17000  2010  Individual
# 1051                     Honda CB twister          16000  2012  Individual
# 1052                   Bajaj Discover 125          15000  2013  Individual
# 1053                       Honda CB Shine          12000  2009  Individual
# 1054                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.shape
# Out:
# (1055, 7)

# %% [markdown]
# ##**Questions:**

# %% [markdown]
# ## Q1. What is the range of selling prices in the dataset?

# %%
lowest = df['selling_price'].min()
highest = df['selling_price'].max()
range_of_selling_price = highest - lowest
print("Range of selling price =", range_of_selling_price)
# Out:
# Range of selling price = 755000

# %% [markdown]
# ##Q2. What is the median selling price for bikes in the dataset?

# %%
np.median(df['selling_price'])
# Out:
# np.float64(45000.0)

# %%
#insights >>> median selling price of bikes is Rs.45000

# %% [markdown]
# ##Q3. What is the most common seller type?

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual    1049
# Dealer           6
# Name: count, dtype: int64

# %%
#insights >>> The most common seller type is "Individual"

# %% [markdown]
# ##Q4. How many bikes have driven more than 50,000 kilometers?

# %%
df[df['km_driven'] > 50000]
# Out:
#                                name  selling_price  year seller_type  \
# 5                  Honda CB Twister          18000  2010  Individual
# 15    Suzuki Access 125 [2007-2016]          25000  2012  Individual
# 20             Hero Passion Pro 110          15000  2008  Individual
# 31          Yamaha FZ S [2012-2016]          38000  2013  Individual
# 43                Hero Passion XPro          28000  2012  Individual
# ...                             ...            ...   ...         ...
# 1043            Hero Super Splendor          20000  2007  Individual
# 1044               Bajaj Pulsar 150          20000  2010  Individual
# 1050                      Activa 3g          17000  2010  Individual
# 1053                 Honda CB Shine          12000  2009  Individual
# 1054               Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# 5     1st owner      60000            53857.0
# ...

# %%
df[df['km_driven'] > 50000].shape
# Out:
# (168, 7)

# %%
#insights >>> 168 bikes have been driven for more than 50,000 kilometers

# %% [markdown]
# ##Q5. What is the average km_driven value for each ownership type?

# %%
df.groupby(['owner'])['km_driven'].mean()
# Out:
# owner
# 1st owner     32732.710240
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
#insights >>> average km_driven value for 1st owner is 32732.710240 km
#         >>> average km_driven value for 2nd owner is 39288.991870 km
#         >>> average km_driven value for 3rd owner is 33292.181818 km
#         >>> average km_driven value for 4th owner is 311500.000 km

# %% [markdown]
# ##Q6. What proportion of bikes are from the year 2015 or older?

# %%
df['year'].unique()
# Out:
# array([2019, 2017, 2018, 2015, 2011, 2010, 2008, 2016, 2020, 2012, 2006,
#        2013, 2009, 2014, 2004, 2007, 2000, 2002, 2005, 1997, 2001, 1988,
#        1999, 1998, 1991, 2003, 1993, 1995])

# %%
df[df['year'] >= 2015]
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 6                    Honda CB Hornet 160R          78500  2018  Individual
# ...                                   ...            ...   ...         ...
# 1037                   Bajaj Discover 100          27000  2015  Individual
# 1041                     Honda CB twister          25000  2015  Individual
# 1042                         Hero Glamour          25000  2015  Individual
# 1047                   Hero  Ignitor Disc          20000  2015  Individual
# 1049                        Bajaj  ct 100          18000  2017  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df[df['year'] >= 2015].shape
# Out:
# (558, 7)

# %%
#insights >>> 558 bikes are from the year 2015 or older

# %% [markdown]
# ##Q7. What is the trend of missing values across the dataset?

# %%
df.isnull().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    433
# dtype: int64

# %%
#insights >>> all the columns have zero missing values except ex_showroom_price which has 433 missing values

# %% [markdown]
# ##Q8. What is the highest ex_showroom_price recorded, and for which bike?

# %%
df.groupby(['name'])['ex_showroom_price'].sum().sort_values(ascending=False)
# Out:
# name
# Honda CB Hornet 160R              1876135.0
# Bajaj Pulsar 180                  1700220.0
# Yamaha FZ S V 2.0                 1356984.0
# Harley-Davidson Street Bob        1278000.0
# Kawasaki Ninja 650 [2018-2019]    1188000.0
#                                     ...
# Bajaj Platina 100                       0.0
# Bajaj Discover 135                      0.0
# Vespa SXL 149                           0.0
# Aprilia SR 125                          0.0
# Yamaha Fazer Dlx                        0.0
# Name: ex_showroom_price, Length: 279, dtype: float64

# %%
#insights >>> Honda CB Hornet 160R has the highest ex_showroom_price recorded

# %% [markdown]
# ##Q9. What is the total number of bikes listed by each seller type?

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual    1049
# Dealer           6
# Name: count, dtype: int64

# %%
#insights >>> Individual seller type- 1049 bikes
#         >>> Dealer seller type- 6 bikes

# %% [markdown]
# ##Q10. What is the relationship between selling_price and km_driven for first-owner bikes?

# %%
x = df[df['owner'] == '1st owner']['km_driven']
y = df[df['owner'] == '1st owner']['selling_price']

plt.figure(figsize = (8,7))
plt.scatter(x,y)
plt.xlabel('km_driven')
plt.ylabel('selling_price')
plt.title('Relationship between selling_price and km_driven for first-owner bikes')
plt.show()

# %%
#insights >>> for most 1st owner bikes both selling price and km driven are low

# %% [markdown]
# ##Q11. Identify and remove outliers in the km_driven column using the IQR method.

# %%
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(Q1)
print(Q3)
print(IQR)
print(lower_bound)
print(upper_bound)
df[~((df['km_driven'] >= lower_bound) & (df['km_driven'] <= upper_bound))]
# Out:
# 13500.0
# 43000.0
# 29500.0
# -30750.0
# 87250.0
#                                  name  selling_price  year seller_type  \
# 91           Honda Activa [2000-2015]          22989  2012  Individual
# 93                      Suzuki GS150R          30000  2010  Individual
# 115           Hero Honda Passion Plus           7500  2004  Individual
# 135            Hero Honda CBZ extreme          20000  2007  Individual
# 154                Hero Xtreme Sports          22000  2014  Individual
# 184              Honda CB Unicorn 160          75000  2015  Individual
# 362                Hero Honda CD100SS          10000  1997  Individual
# 469          Honda Activa [2000-2015]          23000  2009  Individual
# 473     Hero Honda Passion PRO [2012]          12000  2012  Individual
# 476          Honda Activa [2000-2015]          25000  2009  Individual
# 509                Hero Splendor Plus          12000  2007  Individual
# ...

# %%
df_without_outliers_km_driven = df[(df['km_driven'] >= lower_bound) & (df['km_driven'] <= upper_bound)]
df_without_outliers_km_driven
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1048                     Hero  CBZ Xtreme          20000  2010  Individual
# 1049                        Bajaj  ct 100          18000  2017  Individual
# 1051                     Honda CB twister          16000  2012  Individual
# 1052                   Bajaj Discover 125          15000  2013  Individual
# 1053                       Honda CB Shine          12000  2009  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %% [markdown]
# ##Q12. Perform a bivariate analysis to visualize the relationship between year and selling_price.

# %%
x = df['year']
y = df['selling_price']

plt.figure(figsize = (8,7))

plt.scatter(x,y)
plt.xlabel('year')
plt.ylabel('selling_price')
plt.title('Relationship between year and selling_price')
plt.show()

# %% [markdown]
# ##Q13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?

# %%
df['depreciation'] = df['selling_price'] - df['ex_showroom_price']
df['depreciation'].mean()
# Out:
# np.float64(-28495.40353697749)

# %%
#insights >>> -28495.40353697749 is the average depreciation in selling price based on the bike's age

# %% [markdown]
# ##Q14. Which bike names are priced significantly above the average price for their manufacturing year?

# %%
average_price_by_year = df.groupby('year')['selling_price'].mean()

df_with_average_price = pd.merge(df, average_price_by_year, on='year', suffixes=('', '_avg'))

df_above_average = df_with_average_price[df_with_average_price['selling_price'] > df_with_average_price['selling_price_avg'] * 1.5]

print(df_above_average['name'])
# Out:
# 2       Royal Enfield Classic Gunmetal Grey
# 7      Royal Enfield Bullet 350 [2007-2011]
# 13                            Yamaha YZF R3
# 18      Royal Enfield Classic Gunmetal Grey
# 23                            Jawa Standard
#                        ...
# 973               Royal Enfield Thunder 500
# 975               Royal Enfield Thunder 350
# 977               Royal Enfield Classic 350
# 978               Royal Enfield Classic 500
# 979               Royal Enfield Classic 500
# Name: name, Length: 157, dtype: object

# %% [markdown]
# ##Q15. Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1055 non-null   object
#  1   selling_price      1055 non-null   int64
#  2   year               1055 non-null   int64
#  3   seller_type        1055 non-null   object
#  4   owner              1055 non-null   object
#  5   km_driven          1055 non-null   int64
#  6   ex_showroom_price  622 non-null    float64
#  7   depreciation       622 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 66.1+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                    selling_price      year  km_driven  ex_showroom_price  \
# selling_price           1.000000  0.400947  -0.212005           0.918659
# year                    0.400947  1.000000  -0.287227           0.124832
# km_driven              -0.212005 -0.287227   1.000000          -0.120752
# ex_showroom_price       0.918659  0.124832  -0.120752           1.000000
# depreciation           -0.346646  0.343829  -0.065957          -0.689006
#
#                    depreciation
# selling_price         -0.346646
# year                   0.343829
# km_driven             -0.065957
# ex_showroom_price     -0.689006
# depreciation           1.000000

# %%
#plotting heatmap
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(numeric_only=True), annot = True)
plt.show()

# %% [markdown]
# # **EDA - 2**

# %% [markdown]
# ## **About - Dataset:**

# %% [markdown]
# Here is the dataset link: https://drive.google.com/file/d/1N0kM_zi-iU3yvr6BEJf21aiF599PtA0U/view
#
# The dataset provided focuses on used car sales, capturing various attributes to analyze the second-hand car
# market. This dataset provides insights into factors affecting resale value, trends in the used car industry, and
# consumer behavior.
#
# **Title: Car Sale Dataset**
#
#
# **Source:**
#
# The dataset is available on Kaggle, representing data commonly seen in online car resale platforms.
#
#
# **Description:**
#
# The dataset contains details about used cars listed for sale, such as brand, model, selling price, kilometers
# driven, fuel type, and transmission type. This information is valuable for predictive modeling, market analysis,
# and understanding customer preferences.
#
# - Car_id: A unique identifier for each car in the dataset, helping to track individual car entries.
#
# - Date: The date when the car sale transaction took place, formatted as YYYY-MM-DD.
# - Customer Name: The name of the customer who purchased the car, represented as a string.
# - Gender: The gender of the customer, categorized as "Male" or "Female..
# - Annual Income: The customer's annual income in US dollars, represented as a numeric value.
# - Dealer_Name: The name of the dealership selling the car, represented as a string.
# - Company: The manufacturer or brand name of the car, such as "Toyota," "Ford," etc.
# - Model: The specific model name of the car, such as "Corolla," "Civic," etc.
# - Engine: The engine type of the car, such as "V6," "I4," etc.
# - Transmission: The type of transmission in the car, either "Manual" or "Automatic.
# - Color: The color of the car, represented as a string (e.g., "Red," "Blue").
# - Price ($): The selling price of the car in US dollars.
# - Dealer_No: A unique identifier for each car dealer in the dataset.
# - Body Style: The body style of the car, such as "Sedan," "SUV," etc.
# - Phone: The phone number of the customer who purchased the car.
# - Dealer_Region: The geographical region of the car dealer, such as "North," "South," etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/Car Sale.csv')

# %%
df1
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (23906, 16)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %% [markdown]
# ## **QUESTIONS:**

# %% [markdown]
# ## Q1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?

# %%
df1.groupby(['Dealer_Name'])['Price ($)'].mean().sort_values(ascending=False)
# Out:
# Dealer_Name
# U-Haul CO                                          28769.919006
# Classic Chevy                                      28602.014446
# Rabun Used Car Sales                               28527.536177
# Iceberg Rentals                                    28522.958533
# Enterprise Rent A Car                              28312.580800
# Scrivener Performance Engineering                  28297.371589
# Gartner Buick Hyundai Saab                         28247.621019
# Saab-Belle Dodge                                   28190.139888
# Capitol KIA                                        28189.703822
# Race Car Help                                      28163.372706
# Chrysler of Tri-Cities                             28123.091054
# Star Enterprises Inc                               28113.055244
# Suburban Ford                                      28112.206758
# C & M Motors Inc                                   28111.755200
# ...

# %%
#insights >>> dealers like U-Haul CO, Classic Chevy may be selling higher-end or specialty vehicles,
#             while dealers like Pitre Buick-Pontiac-Gmc of Scottsdale and Chrysler Plymouth may be selling more affordable options.

# %% [markdown]
# ##Q2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?

# %%
df1.groupby(['Company'])['Price ($)'].std().sort_values(ascending=False)
# Out:
# Company
# Lincoln       19658.050211
# Saab          19653.740089
# Cadillac      19517.120220
# Plymouth      19065.997338
# Lexus         17852.923492
# Buick         17142.232626
# Mercury       16445.172195
# Nissan        16214.264017
# Saturn        15990.223671
# Ford          15849.090227
# Mercedes-B    15722.807459
# Oldsmobile    15711.345857
# Toyota        15367.131714
# BMW           15065.578723
# Pontiac       14348.963592
# Infiniti      13696.332844
# Chevrolet     13311.063223
# Volvo         12933.790185
# Subaru        12920.771620
# Audi          12904.243867
# Volkswagen    12527.124011
# Mitsubishi    11671.343035
# Chrysler      11583.286811
# Dodge         11187.592085
# Honda         11148.629062
# Jaguar        10222.531533
# Jeep           9459.834418
# Acura          8183.046414
# Porsche        5261.839206
# Hyundai        3485.982649
# Name: Price ($), dtype: float64

# %%
# insights >>> The car brand with the highest variation in prices is Lincoln, with a std of $19,658.05
#          >>> brands like Porsche and Hyundai have lower standard deviations, indicating more consistent pricing strategies

# %% [markdown]
# ## Q3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

# %%
transmission_stats = df1.groupby(['Transmission'])['Price ($)'].describe()

# %%
transmission_stats
# Out:
#                 count          mean           std     min      25%      50%  \
# Transmission
# Auto          12571.0  28248.525972  13747.070597  1200.0  19000.0  24000.0
# Manual        11335.0  27914.710631  15862.871978  1700.0  17000.0  22001.0
#
#                   75%      max
# Transmission
# Auto          35500.0  75700.0
# Manual        34000.0  85800.0

# %%
print(transmission_stats['75%'] - transmission_stats['25%'])
# Out:
# Transmission
# Auto      16500.0
# Manual    17000.0
# dtype: float64

# %%
#insights >>> the prices of manual transmission cars are slightly more spread out than those of automatic transmission cars.

# %% [markdown]
# ##Q4. What is the distribution of car prices across different regions?

# %%
#What is the distribution of car prices across different regions
df1.groupby(['Dealer_Region'])['Price ($)'].value_counts()
# Out:
# Dealer_Region  Price ($)
# Aurora         22000        155
#                19000        127
#                21000        122
#                26000         96
#                18000         81
#                            ...
# Scottsdale     71210          1
#                71580          1
#                71990          1
#                82500          1
#                82750          1
# Name: count, Length: 2447, dtype: int64

# %%
df1.groupby('Dealer_Region')['Price ($)'].describe()
# Out:
#                 count          mean           std     min      25%      50%  \
# Dealer_Region
# Aurora         3130.0  28334.626837  15026.207252  9000.0  18001.0  23000.0
# Austin         4135.0  28341.603628  14903.884549  9000.0  18001.0  23801.0
# Greenville     3128.0  28180.819054  15101.538328  1200.0  18001.0  22500.0
# Janesville     3821.0  27833.350955  14344.995638  4300.0  18001.0  23000.0
# Middletown     3128.0  27856.338875  14619.842395  1700.0  18000.0  22750.0
# Pasco          3131.0  28119.039923  14659.315941  9000.0  18500.5  23000.0
# Scottsdale     3433.0  27954.958928  14902.916820  1450.0  18000.0  22600.0
#
#                    75%      max
# Dealer_Region
# Aurora         35000.0  85800.0
# Austin         35001.0  85601.0
# Greenville     34500.0  85200.0
# Janesville     34000.0  85400.0
# Middletown     34000.0  85300.0
# Pasco          34000.0  85600.0
# Scottsdale     33500.0  85001.0

# %% [markdown]
# ## Q5. What is the distribution of cars based on body styles?

# %%
df1['Body Style'].value_counts()
# Out:
# Body Style
# SUV          6374
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2971
# Name: count, dtype: int64

# %% [markdown]
# ## Q6.  How does the average selling price of cars vary by customer gender and annual income?

# %%
df1.groupby(['Gender'])['Price ($)'].mean()
# Out:
# Gender
# Female    28277.265270
# Male      28039.429407
# Name: Price ($), dtype: float64

# %%
#insights >>> The difference between the two averages is:
#         >>> $28,277.27 (female) - $28,039.43 (male) = $237.84
#         >>> on average, female customers purchase cars that are approximately $238 more expensive than those purchased by Male customers.

# %%
df1.groupby(['Annual Income'])['Price ($)'].mean()
# Out:
# Annual Income
# 10080       22801.000000
# 13500       27878.981415
# 24000       61001.000000
# 85000       43000.000000
# 106000      46001.000000
#                 ...
# 6600000     39000.000000
# 6800000     15000.000000
# 7650000     21000.000000
# 8000000     85000.000000
# 11200000    26001.000000
# Name: Price ($), Length: 2508, dtype: float64

# %% [markdown]
# ## Q7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?

# %%
df1.groupby(['Dealer_Region'])['Price ($)'].sum()
# Out:
# Dealer_Region
# Aurora         88687382
# Austin        117192531
# Greenville     88149602
# Janesville    106351234
# Middletown     87134628
# Pasco          88040714
# Scottsdale     95969374
# Name: Price ($), dtype: int64

# %%
df1.groupby(['Dealer_Region'])['Price ($)'].describe()
# Out:
#                 count          mean           std     min      25%      50%  \
# Dealer_Region
# Aurora         3130.0  28334.626837  15026.207252  9000.0  18001.0  23000.0
# Austin         4135.0  28341.603628  14903.884549  9000.0  18001.0  23801.0
# Greenville     3128.0  28180.819054  15101.538328  1200.0  18001.0  22500.0
# Janesville     3821.0  27833.350955  14344.995638  4300.0  18001.0  23000.0
# Middletown     3128.0  27856.338875  14619.842395  1700.0  18000.0  22750.0
# Pasco          3131.0  28119.039923  14659.315941  9000.0  18500.5  23000.0
# Scottsdale     3433.0  27954.958928  14902.916820  1450.0  18000.0  22600.0
#
#                    75%      max
# Dealer_Region
# Aurora         35000.0  85800.0
# Austin         35001.0  85601.0
# Greenville     34500.0  85200.0
# Janesville     34000.0  85400.0
# Middletown     34000.0  85300.0
# Pasco          34000.0  85600.0
# Scottsdale     33500.0  85001.0

# %%
df1.groupby(['Dealer_Region'])['Price ($)'].count()
# Out:
# Dealer_Region
# Aurora        3130
# Austin        4135
# Greenville    3128
# Janesville    3821
# Middletown    3128
# Pasco         3131
# Scottsdale    3433
# Name: Price ($), dtype: int64

# %%
#insights >>> maximum cars are sold iin Aurora region and least cars are sold in Scottsdale region

# %% [markdown]
# ## Q8. How does the average car price differ between cars with different engine sizes?

# %%
df1.groupby(['Engine'])['Price ($)'].mean()
# Out:
# Engine
# DoubleÂ Overhead Camshaft    28248.525972
# Overhead Camshaft            27914.710631
# Name: Price ($), dtype: float64

# %%
#insights >>> DoubleÂ Overhead Camshaft	engine has more average price than that of overhead camshaft

# %% [markdown]
# ## Q9. How do car prices vary based on the customer’s annual income bracket?

# %%
income_brackets = [0, 20000, 50000, 100000, 200000]
df1['income_brackets'] = pd.cut(df1['Annual Income'], bins = income_brackets)

df1.groupby('income_brackets')['Price ($)'].mean()
# Out:
# <ipython-input-1162-29ec0f5fdcdf>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby('income_brackets')['Price ($)'].mean()
# income_brackets
# (0, 20000]          27878.018582
# (20000, 50000]      61001.000000
# (50000, 100000]     43000.000000
# (100000, 200000]    22833.666667
# Name: Price ($), dtype: float64

# %%
#insights >>> The middle-income bracket has the highest average car price
#         >>> The highest income bracket has a lower average car price than the upper-middle-income bracket.

# %% [markdown]
# ## Q10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?

# %%
z= df1.groupby(['Model'])['Price ($)'].count().sort_values(ascending=False).head(5)
z
# Out:
# Model
# Diamante      418
# Prizm         411
# Silhouette    411
# Passat        391
# Ram Pickup    383
# Name: Price ($), dtype: int64

# %%
plt.figure(figsize= (10,7))

top_5_models = z.index

for model in top_5_models:
    model_data = df1[df1['Model'] == model]['Price ($)']
    plt.hist(model_data, label=model, alpha=0.7)

plt.xticks(rotation = 90)
plt.legend()
plt.title('Price Distribution of Top 5 Car Models')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.show()

# %%
# INSIGHTS >>>  Diamante, Prizm, Silhouette, Passat, Ram Pickup are the top 5 car models with the highest number of sales

# %% [markdown]
# ## Q11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?

# %%
df1.groupby(['Color', 'Engine'])['Price ($)'].std().reset_index()
# Out:
#         Color                     Engine     Price ($)
# 0       Black  DoubleÂ Overhead Camshaft  12418.674126
# 1       Black          Overhead Camshaft  17457.405345
# 2  Pale White  DoubleÂ Overhead Camshaft  14402.413401
# 3  Pale White          Overhead Camshaft  13000.103061
# 4         Red  DoubleÂ Overhead Camshaft  13499.354247
# 5         Red          Overhead Camshaft  17346.642554

# %%
#insights >>> The colors with the highest price variation (std dev) are:
#         >>> 1. Black with Overhead Camshaft engine: $17,457.41
#         >>> 2. Red with Overhead Camshaft engine: $17,346.64

# %% [markdown]
# ## Q12. Is there any seasonal trend in car sales based on the date of sale?

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1['Month'] = df1['Date'].dt.month
df1['Year'] = df1['Date'].dt.year
a = df1.groupby(['Month', 'Year'])['Price ($)'].count()
a
# Out:
# Month  Year
# 1      2022     315
#        2023     475
# 2      2022     320
#        2023     415
# 3      2022     705
#        2023     830
# 4      2022     800
#        2023     855
# 5      2022     750
#        2023    1145
# 6      2022     690
#        2023    1025
# 7      2022     700
#        2023    1025
# 8      2022     810
#        2023     895
# 9      2022    1475
#        2023    1830
# 10     2022     835
#        2023     995
# 11     2022    1620
#        2023    1850
# 12     2022    1625
#        2023    1921
# Name: Price ($), dtype: int64

# %%
#insights >>> Peaks: September (1475 and 1830), November (1620 and 1850), and December (1625 and 1921)
#         >>> Troughs: January (315 and 475), February (320 and 415)
#         >>> Yearly Trend: Sales appear to be increasing from 2022 to 2023.

# %% [markdown]
# ## Q13. How does the car price distribution change when considering different combinations of body style and transmission type?

# %%
df1.groupby(['Body Style', 'Transmission'])['Price ($)'].describe()
# Out:
#                           count          mean           std      min      25%  \
# Body Style Transmission
# Hardtop    Auto          1408.0  31520.188210  13687.756740  12000.0  21001.0
#            Manual        1563.0  27016.943698  14072.501848  11000.0  17575.5
# Hatchback  Auto          3458.0  25910.544824  13144.014337   4200.0  18001.0
#            Manual        2670.0  28702.550562  16284.049616   1700.0  17000.0
# Passenger  Auto          2020.0  28915.835149  13946.481932   9000.0  19000.0
#            Manual        1925.0  28969.521039  18523.684163  10000.0  16001.0
# SUV        Auto          3086.0  27501.404407  13299.927913   1200.0  19000.0
#            Manual        3288.0  26079.019161  14621.526541   2200.0  17000.0
# Sedan      Auto          2599.0  29955.294344  14310.910860  12000.0  19000.0
#            Manual        1889.0  29664.271572  15440.056434  11000.0  19001.0
#
#                              50%      75%      max
# Body Style Transmission
# ...

# %%
#insights >>> - Hardtops with auto transmissions tend to have higher prices and less variability in prices.
#         >>> - Hatchbacks with manual transmissions tend to have higher prices and more variability in prices.
#         >>> - SUVs with manual transmissions tend to have lower prices and more variability in prices.
#         >>> - Sedans with auto transmissions tend to have higher prices and less variability in prices.

# %% [markdown]
# ## Q14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1['Engine_size'] = le.fit_transform(df1['Engine'])
df1.corr(numeric_only=True)
# Out:
#                Annual Income  Price ($)     Phone     Month      Year  \
# Annual Income       1.000000   0.012065 -0.000351 -0.015141 -0.031406
# Price ($)           0.012065   1.000000 -0.000493  0.006856 -0.007511
# Phone              -0.000351  -0.000493  1.000000  0.005470  0.006815
# Month              -0.015141   0.006856  0.005470  1.000000 -0.023009
# Year               -0.031406  -0.007511  0.006815 -0.023009  1.000000
# Engine_size        -0.006598  -0.011271 -0.005254 -0.009640  0.009324
#
#                Engine_size
# Annual Income    -0.006598
# Price ($)        -0.011271
# Phone            -0.005254
# Month            -0.009640
# Year              0.009324
# Engine_size       1.000000

# %%
#insights >>> - There is a weak +ve correlation between annual income and car price, suggesting that customers with higher incomes tend to buy more expensive cars.
#         >>> - There is a weak -ve correlation between engine size and car price
#         >>> - The correlations between annual income, engine size, and car price are relatively weak, suggesting that other factors may affect car prices.

# %% [markdown]
# ## Q15. How does the average car price vary across different car models and engine types?

# %%
df1.groupby(['Model', 'Engine'])['Price ($)'].mean()
# Out:
# Model     Engine
# 3-Sep     DoubleÂ Overhead Camshaft    37986.380117
# 3000GT    DoubleÂ Overhead Camshaft    22764.326923
#           Overhead Camshaft            21770.659864
# 300M      DoubleÂ Overhead Camshaft    21394.888889
# 323i      DoubleÂ Overhead Camshaft    16744.632287
#                                            ...
# Windstar  Overhead Camshaft            17100.272727
# Wrangler  DoubleÂ Overhead Camshaft    21145.294737
#           Overhead Camshaft            18742.942029
# Xterra    DoubleÂ Overhead Camshaft    15940.459459
#           Overhead Camshaft            31072.500000
# Name: Price ($), Length: 261, dtype: float64

# %%
df1.groupby(['Model', 'Engine'])['Price ($)'].mean().head(30)
# Out:
# Model    Engine
# 3-Sep    DoubleÂ Overhead Camshaft    37986.380117
# 3000GT   DoubleÂ Overhead Camshaft    22764.326923
#          Overhead Camshaft            21770.659864
# 300M     DoubleÂ Overhead Camshaft    21394.888889
# 323i     DoubleÂ Overhead Camshaft    16744.632287
#          Overhead Camshaft            21038.162162
# 328i     DoubleÂ Overhead Camshaft    21069.149606
#          Overhead Camshaft            38676.177215
# 4Runner  DoubleÂ Overhead Camshaft    32167.794118
#          Overhead Camshaft            25075.416667
# 5-Sep    DoubleÂ Overhead Camshaft    41067.000000
#          Overhead Camshaft            28071.454545
# 528i     DoubleÂ Overhead Camshaft    46288.712963
#          Overhead Camshaft            21197.898148
# A4       DoubleÂ Overhead Camshaft    27070.500000
#          Overhead Camshaft            12046.220000
# A6       DoubleÂ Overhead Camshaft    25458.258929
#          Overhead Camshaft            21220.262673
# ...

# %%
#insights >>> - Most expensive model: Aurora with Overhead Camshaft engine: $51,834
#             - Least expensive model: A4 with Overhead Camshaft engine: $12,046
#         >>> Engine type impact on price: Double Overhead Camshaft engines tend to be more expensive than Overhead Camshaft engines for the same model.

# %% [markdown]
# # **EDA - 3**

# %% [markdown]
# Amazon Sales Data
#
#
# **Description:**
#
# This dataset contains information on 1K+ Amazon products, including their ratings, reviews, and other details.
#
# **Features:**
#
# - product_id: Unique identifier for each product
#
# - product_name: Name of the product
#
# - category: Category of the product
#
# - discounted_price: Discounted price of the product
#
# - actual_price: Actual price of the product
#
# - discount_percentage: Percentage of discount for the product
#
# - rating: Rating of the product (1-5)
#
# - rating_count: Number of people who voted for the Amazon rating
#
# - about_product: Description about the product
#
# - user_id: ID of the user who wrote the review
#
# - user_name: Name of the user who wrote the review
#
# - review_id: ID of the user review
#
# - review_title: Short review
#
# - review_content: Long review
#
# - img_link: Image link of the product
#
# - product_link: Official website link of the product
#
#
# **Source:** https://drive.google.com/file/d/1yKlW0x5yyRQijmWbEg5YCsq4wqLl3_oB/view

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 = pd.read_csv('/content/amazon.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.shape
# Out:
# (1465, 16)

# %%
df2.rating.unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df2[~df2.rating.str.isnumeric()]
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1458  B07J9KXQCC  Libra Room Heater for Home, Room Heaters Home ...
# 1459  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df2['rating'] = pd.to_numeric(df2['rating'], errors='coerce')

df2.dropna(subset=['rating'], inplace=True)

df2['rating'] = df2['rating'].astype(float)

# %%
df2.rating
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460    4.0
# 1461    4.1
# 1462    3.6
# 1463    4.0
# 1464    4.3
# Name: rating, Length: 1464, dtype: float64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1464 non-null   object
#  1   product_name         1464 non-null   object
#  2   category             1464 non-null   object
#  3   discounted_price     1464 non-null   object
#  4   actual_price         1464 non-null   object
#  5   discount_percentage  1464 non-null   object
#  6   rating               1464 non-null   float64
#  7   rating_count         1462 non-null   object
#  8   about_product        1464 non-null   object
#  9   user_id              1464 non-null   object
#  10  user_name            1464 non-null   object
#  11  review_id            1464 non-null   object
#  12  review_title         1464 non-null   object
#  13  review_content       1464 non-null   object
#  14  img_link             1464 non-null   object
# ...

# %%
df2.shape
# Out:
# (1464, 16)

# %%
df2.rating_count.unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df2['rating_count'] = pd.to_numeric(df2['rating_count'], errors='coerce')
df2['rating_count'] = df2['rating_count'].astype(float)
df2.rating_count
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1460      NaN
# 1461      NaN
# 1462    468.0
# 1463      NaN
# 1464      NaN
# Name: rating_count, Length: 1464, dtype: float64

# %%
df2.shape
# Out:
# (1464, 16)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1464 non-null   object
#  1   product_name         1464 non-null   object
#  2   category             1464 non-null   object
#  3   discounted_price     1464 non-null   object
#  4   actual_price         1464 non-null   object
#  5   discount_percentage  1464 non-null   object
#  6   rating               1464 non-null   float64
#  7   rating_count         325 non-null    float64
#  8   about_product        1464 non-null   object
#  9   user_id              1464 non-null   object
#  10  user_name            1464 non-null   object
#  11  review_id            1464 non-null   object
#  12  review_title         1464 non-null   object
#  13  review_content       1464 non-null   object
#  14  img_link             1464 non-null   object
# ...

# %%
df2.actual_price.unique()
# Out:
# array(['₹1,099', '₹349', '₹1,899', '₹699', '₹399', '₹1,000', '₹499',
#        '₹299', '₹999', '₹339', '₹799', '₹700', '₹899', '₹24,999',
#        '₹21,990', '₹1,799', '₹22,900', '₹199', '₹19,990', '₹19,999',
#        '₹1,999', '₹750', '₹599', '₹666.66', '₹1,900', '₹45,999', '₹695',
#        '₹34,999', '₹1,599', '₹1,208', '₹475', '₹395', '₹2,199', '₹500',
#        '₹2,100', '₹12,999', '₹1,399', '₹21,999', '₹1,499', '₹47,900',
#        '₹845', '₹1,400', '₹14,990', '₹2,999', '₹42,999', '₹30,990',
#        '₹3,999', '₹249', '₹19,125', '₹1,299', '₹39,999', '₹40,990',
#        '₹52,900', '₹800', '₹31,999', '₹1,809', '₹29,999', '₹65,000',
#        '₹20,000', '₹23,990', '₹15,999', '₹44,990', '₹44,999', '₹1,700',
#        '₹595', '₹27,990', '₹1,200', '₹34,990', '₹1,500', '₹49,990',
#        '₹931', '₹2,399', '₹1,339', '₹20,900', '₹15,990', '₹1,600', '₹849',
#        '₹1,199', '₹22,990', '₹2,499', '₹47,990', '₹485', '₹18,990',
# ...

# %% [markdown]
# ## **QUESTIONS:**

# %% [markdown]
# ## Q1. What is the average rating for each product category?

# %%
df2.groupby(['category'])['rating'].mean()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.800000
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.150000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.500000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.600000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.050000
#                                                                                                                             ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.250000
# ...

# %% [markdown]
# ## Q2. What are the top rating_count products by category?

# %%
df_sorted = df2.sort_values('rating_count', ascending=False)
df_sorted[['category', 'product_name', 'rating_count']].head(10)
# Out:
#                                                category  \
# 750   Electronics|GeneralPurposeBatteries&BatteryCha...
# 1059  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 32    Computers&Accessories|Accessories&Peripherals|...
# 823   Computers&Accessories|Accessories&Peripherals|...
# 151   Computers&Accessories|Accessories&Peripherals|...
# 1272  Home&Kitchen|Heating,Cooling&AirQuality|WaterH...
# 1259  Home&Kitchen|Heating,Cooling&AirQuality|WaterH...
# 214   Electronics|HomeTheater,TV&Video|Accessories|R...
# 1262  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 147   Computers&Accessories|Accessories&Peripherals|...
#
#                                            product_name  rating_count
# 750        Eveready Red 1012 AAA Batteries - Pack of 10         989.0
# 1059  Pigeon 1.5 litre Hot Kettle and Stainless Stee...         976.0
# 32    Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...         974.0
# ...

# %% [markdown]
# ## Q3. What is the distribution of discounted prices vs. actual prices?

# %%
df2['discounted_price'] = pd.to_numeric(df2['discounted_price'].str.replace('[^0-9.]', '', regex=True), errors='coerce')
df2['actual_price'] = pd.to_numeric(df2['actual_price'].str.replace('[^0-9.]', '', regex=True), errors='coerce')


plt.figure(figsize=(10, 6))
plt.hist(df2['discounted_price'], bins=20, alpha=0.5, label='Discounted Price')
plt.hist(df2['actual_price'], bins=20, alpha=0.5, label='Actual Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Discounted Prices vs. Actual Prices')
plt.legend()
plt.show()

# %% [markdown]
# ## Q4. How does the average discount percentage vary across categories?

# %%
df2['discount_percentage'] = pd.to_numeric(df2['discount_percentage'].str.replace('%', ''), errors='coerce')
df2.groupby('category')['discount_percentage'].mean()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    42.0
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   78.5
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           35.0
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        56.5
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           46.5
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         0.0
# ...

# %% [markdown]
# ## Q5. What are the most popular product names?

# %%
df2['product_name'].value_counts().sort_values(ascending=False).head(10)
# Out:
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                       5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                4
# Portronics Konnect L POR-1081 Fast Charging 3A Type-C Cable 1.2Meter with Charge & Sync Function for All Type-C Devices (Grey)                                                  3
# Flix Micro Usb Cable For Smartphone (Black)                                                                                                                                     3
# Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)                                                 3
# ...

# %%
#insights >>> the most popular pdoducts are
#             1. Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution
#             2. Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating

# %% [markdown]
# ## Q6. What are the most popular product keywords?

# %%
from collections import Counter

all_product_names = " ".join(df2['product_name'].astype(str).tolist())

words = all_product_names.lower().split()

word_counts = Counter(words)

for word, count in word_counts.most_common(5):
    print(f"{word}: {count}")
# Out:
# with: 750
# for: 672
# |: 457
# &: 431
# usb: 377

# %% [markdown]
# ## Q7. What are the most popular product reviews?

# %%
df2['review_title'].value_counts().head(10)  # Shows the top 10 most frequent review titles
# Out:
# review_title
# Worked on iPhone 7 and didn’t work on XR,Good one,Dull Physical Looks,Just Buy it,Go for it,About the product,Get charging cable at the price,Working well.                                                                                                                                     10
# Satisfied,Charging is really fast,Value for money,Product review,Good quality,Good product,Good Product,As of now seems good                                                                                                                                                                     8
# Phone, camera, heating - works for me, may not for all,Good Mobile,Good but not excellent under this budget,Worth the price at 9499,Ok type phone... but unable to make videocall within same service provider.,Phone review,Budget king,Battery backup is good                                  8
# ...

# %% [markdown]
# ## Q8. What is the correlation between discounted_price and rating?

# %%
df2.corr(numeric_only=True)
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961919            -0.242740
# actual_price                 0.961919      1.000000            -0.118459
# discount_percentage         -0.242740     -0.118459             1.000000
# rating                       0.120337      0.121642            -0.155375
# rating_count                -0.010780     -0.013003            -0.005179
#
#                        rating  rating_count
# discounted_price     0.120337     -0.010780
# actual_price         0.121642     -0.013003
# discount_percentage -0.155375     -0.005179
# rating               1.000000      0.112141
# rating_count         0.112141      1.000000

# %%
#insights >>> correlation between discounted price and rating is less positive(0.120337)

# %% [markdown]
# ## Q9.  What are the Top 5 categories based on the highest ratings?

# %%
top_5_categories = df2.groupby('category')['rating'].mean().sort_values(ascending=False).head(5)
top_5_categories
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Computers&Accessories|Components|Memory                                     4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# Name: rating, dtype: float64

# %% [markdown]
# ## Q10. Identify any potential areas for improvement or optimization based on the data analysis.

# %%
# 1. Sentiment Analysis :
#    - Apply sentiment analysis on customer reviews to understand the overall sentiment about specific products or categories.
#    - This can help identify patterns of customer satisfaction and dissatisfaction.

# 2. Recommendation : Build a recommendation system based on the customer reviews and product categories to suggest relevant products to potential buyers.

# %% [markdown]
# # **EDA - 4**

# %% [markdown]
# **Dataset Link:** https://drive.google.com/file/d/1JVgy2yXUOREkzRdCeWjep626uvvF94pP/view
#
#
# **Description of the Dataset:**
#
# The dataset titled "Spotify Data: Popular Hip-hop Artists and Tracks" provides a curated collection of
# approximately 500 entries showcasing the vibrant realm of hip-hop music. These entries meticulously compile
# the most celebrated hip-hop tracks and artists, reflecting their significant influence on the genre's landscape.
# Each entry not only highlights the popularity and musical composition of the tracks but also underscores the
# creative prowess of the artists and their profound impact on global listeners.
#
#
# **Application in Data Science:**
#
# This dataset serves as a valuable resource for various data science explorations. Analysts can delve into trend
# analysis to discern the popularity dynamics of hit hip-hop tracks over recent years. Additionally, the dataset
# enables network analysis to uncover collaborative patterns among top artists, shedding light on the genre's
# evolving collaborative landscape. Furthermore, it facilitates the development of predictive models aimed at
# forecasting track popularity based on diverse features, offering insights for artists, producers, and marketers.
#
# **Column Descriptors:**
#
# Artist: The name of the artist, providing direct attribution to the creative mind behind the track.
#
# Track Name: The title of the track, encapsulating its identity and essence.
#
# Popularity: A numeric score reflecting the track's reception and appeal among Spotify listeners.
#
# Duration (ms): The track's length in milliseconds, detailing the temporal extent of the musical experience.
#
# Track ID: A unique identifier within Spotify's ecosystem, enabling direct access to the track for further
# exploration.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df3 = pd.read_csv('/content/spotify.csv')

# %%
df3.shape
# Out:
# (440, 5)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %% [markdown]
# ## **QUESTIONS :**

# %% [markdown]
# ## Q1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful.

# %%
#checking null values
print(df3.isnull().sum())
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
# So there is no null value

# %%
#checking duplicates
print(df3.duplicated().sum())
# Out:
# 27

# %%
#findng where is the duplicate value with its original value
df3[df3.duplicated(keep=False)]
# Out:
#               Artist                                         Track Name  \
# 3              Drake               First Person Shooter (feat. J. Cole)
# 4              Drake                      Jimmy Cooks (feat. 21 Savage)
# 7       Travis Scott                             MELTDOWN (feat. Drake)
# 9              Drake                                          Rich Flex
# 10       Post Malone      Sunflower - Spider-Man: Into the Spider-Verse
# 22       Nicki Minaj                     Everybody (feat. Lil Uzi Vert)
# 24       Nicki Minaj   Barbie World (with Aqua) [From Barbie The Album]
# 30      Travis Scott                         FE!N (feat. Playboi Carti)
# 34         21 Savage                                            née-nah
# 35      Metro Boomin            Trance (with Travis Scott & Young Thug)
# 38      Travis Scott                   TELEKINESIS (feat. SZA & Future)
# 39      Travis Scott                             MELTDOWN (feat. Drake)
# ...

# %%
#removing duplicates
df3.drop_duplicates(inplace=True)

# %%
#resetting index
df3.reset_index(drop=True, inplace=True)

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
#now there are no duplicated rows

# %% [markdown]
# ## Q2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

# %%
plt.figure(figsize=(10, 6))

plt.hist(df3['Popularity'], bins=20, edgecolor='black')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.title('Distribution of Track Popularity')
plt.show()

# %%
plt.figure(figsize=(50,20))

plt.bar(df3['Track Name'], df3['Popularity'])
plt.xlabel('Track Name')
plt.ylabel('Popularity')
plt.title('Popularity of Tracks')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#insights >>> popularity is mostly distributed between 60 and 90, the plot is negatively skewed

# %% [markdown]
# ## Q3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

# %%
plt.figure(figsize=(15,6))

plt.scatter(df3['Duration (ms)'], df3['Popularity'])
plt.xlabel('Duration (ms)')
plt.ylabel('Popularity')
plt.title('Relationship between Popularity and Duration of Tracks')
plt.show()

# %%
#insights >>> Popularity of tracks is more when duration(ms) is between 100000 and 300000, mostly around 200000

# %% [markdown]
# ## Q4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.

# %%
print(df3.groupby('Artist')['Track Name'].count().sort_values(ascending=False).head(1))
print('\n')

plt.figure(figsize=(25, 6))
sns.countplot(x='Artist', data=df3, order=df3['Artist'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Artist')
plt.ylabel('Number of Tracks')
plt.title('Number of Tracks per Artist')
plt.show()
# Out:
# Artist
# Drake    17
# Name: Track Name, dtype: int64

# %%
#insights >>> Drake has the highest number of tracks in the dataset

# %% [markdown]
# ## Q5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

# %%
df3.sort_values('Popularity').head(5)[['Artist', 'Track Name', 'Popularity']]
# Out:
#              Artist                     Track Name  Popularity
# 199          Pressa  Attachments (feat. Coi Leray)          29
# 219   Justin Bieber                     Intentions          35
# 390  French Montana                Splash Brothers          44
# 213        Lil Baby                  On Me - Remix          47
# 384     Wyclef Jean      911 (feat. Mary J. Blige)          48

# %% [markdown]
# ## Q6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.

# %%
#top 5 popular artists
top5artists = df3.groupby(['Artist'])['Popularity'].sum().sort_values(ascending=False).head(5)
top5artists
# Out:
# Artist
# Drake        1409
# Eminem        920
# ¥$            851
# 21 Savage     838
# Flo Rida      780
# Name: Popularity, dtype: int64

# %%
#average popularity of these 5 artists
drake_avg_popularity = df3[df3['Artist'] == 'Drake']['Popularity'].mean()
eminem_avg_popularity = df3[df3['Artist'] == 'Eminem']['Popularity'].mean()
_dollar_avg_popularity = df3[df3['Artist'] == '¥$']['Popularity'].mean()
_21_savage_avg_popularity = df3[df3['Artist'] == '21 Savage']['Popularity'].mean()
flo_rida_avg_popularity = df3[df3['Artist'] == 'Flo Rida']['Popularity'].mean()

# %%
#displaying averagee popularity
print(f"Drake's average popularity: {drake_avg_popularity}")
print(f"Eminem's average popularity: {eminem_avg_popularity}")
print(f"¥$ average popularity: {_dollar_avg_popularity}")
print(f"21 Savage's average popularity: {_21_savage_avg_popularity}")
print(f"Flo Rida's average popularity: {flo_rida_avg_popularity}")
# Out:
# Drake's average popularity: 82.88235294117646
# Eminem's average popularity: 83.63636363636364
# ¥$ average popularity: 85.1
# 21 Savage's average popularity: 83.8
# Flo Rida's average popularity: 78.0

# %%
#insights >>>  ¥$ has the highest popularity on average

# %% [markdown]
# ## Q7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

# %%
#top 5 popular artists
top5artists = df3.groupby(['Artist'])['Popularity'].sum().sort_values(ascending=False).head(5)
top5artists
# Out:
# Artist
# Drake        1409
# Eminem        920
# ¥$            851
# 21 Savage     838
# Flo Rida      780
# Name: Popularity, dtype: int64

# %%
#most popular tracks of top5artists
drake_most_popular_track = df3[(df3['Artist'] == 'Drake') & (df3['Popularity'] == df3[df3['Artist'] == 'Drake']['Popularity'].max())]['Track Name'].values
eminem_most_popular_track = df3[(df3['Artist'] == 'Eminem') & (df3['Popularity'] == df3[df3['Artist'] == 'Eminem']['Popularity'].max())]['Track Name'].values
_dollar_most_popular_track = df3[(df3['Artist'] == '¥$') & (df3['Popularity'] == df3[df3['Artist'] == '¥$']['Popularity'].max())]['Track Name'].values
_21_savage_most_popular_track = df3[(df3['Artist'] == '21 Savage') & (df3['Popularity'] == df3[df3['Artist'] == '21 Savage']['Popularity'].max())]['Track Name'].values
flo_rida_most_popular_track = df3[(df3['Artist'] == 'Flo Rida') & (df3['Popularity'] == df3[df3['Artist'] == 'Flo Rida']['Popularity'].max())]['Track Name'].values

print(f"Drake's most popular track: {drake_most_popular_track}")
print(f"Eminem's most popular track: {eminem_most_popular_track}")
print(f"¥$ most popular track: {_dollar_most_popular_track}")
print(f"21 Savage's most popular track: {_21_savage_most_popular_track}")
print(f"Flo Rida's most popular track: {flo_rida_most_popular_track}")
# Out:
# Drake's most popular track: ['Rich Baby Daddy (feat. Sexyy Red & SZA)']
# Eminem's most popular track: ['Without Me']
# ¥$ most popular track: ['CARNIVAL']
# 21 Savage's most popular track: ['redrum']
# Flo Rida's most popular track: ['Low (feat. T-Pain)']

# %% [markdown]
# ## Q8. Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
sns.pairplot(df3[['Popularity', 'Duration (ms)']])
plt.show()

# %% [markdown]
# ## Q9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.

# %%
plt.figure(figsize=(25, 8))

sns.boxplot(x='Artist', y='Duration (ms)', data=df3)
plt.xticks(rotation=90)
plt.xlabel('Artist')
plt.ylabel('Duration (ms)')
plt.grid(True)
plt.title('Duration of Tracks Across Different Artists')
plt.show()

# %%
#insights >>> the duration(ms) of most artists lie between 100000 and 300000, mostly around 200000, except dj Khaled, whose duration(ms) is more then 300000

# %% [markdown]
# ## Q10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.

# %%
plt.figure(figsize=(25, 8))

sns.violinplot(x='Artist', y='Popularity', data=df3)
plt.xticks(rotation=90)
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.grid(True)
plt.title('Distribution of Track Popularity for Different Artists')
plt.show()

# %%
#insights >>> most artists have popularity between 60-100
